# %%
import os
os.environ["OPENAI_API_KEY"] = "sk-proj-ORV1HwUGs8R8vWlaRYLdAzJfhxLH9NYWyb5GDGGm9Il4JLsPWQX5L1I8A9hR_Cbs1a0JWaPCtUdqvv5LRedP2mIWl8A"

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# c:\Users\91941\RAG\.venv\Scripts\python.exe
# 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]

# %%
import site
print(site.getsitepackages())
# Out:
# ['c:\\Users\\91941\\RAG\\.venv', 'c:\\Users\\91941\\RAG\\.venv\\Lib\\site-packages']

# %%
import subprocess
subprocess.run([sys.executable, "-m", "pip", "list"])
# Out:
# CompletedProcess(args=['c:\\Users\\91941\\RAG\\.venv\\Scripts\\python.exe', '-m', 'pip', 'list'], returncode=1)

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\91941\RAG\.venv\Scripts\python.exe

# %%
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled
#       2 from langchain.text_splitter import RecursiveCharacterTextSplitter
#       3 from langchain_openai import OpenAIEmbeddings, ChatOpenAI
#       4 from langchain_community.vectorstores import FAISS
#
# ModuleNotFoundError: No module named 'youtube_transcript_api'
